# %% [markdown]
# # Animus: animistic playlist generation

# %% [markdown]
# ## Anthropic stuff

# %%
from dotenv import load_dotenv
import os

load_dotenv('local.env')

anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')

# %%
from langchain_anthropic import ChatAnthropic

llm = ChatAnthropic(
    anthropic_api_key=anthropic_api_key,
    model='claude-3-5-sonnet-20240620'
)

# %%
from langchain.prompts import PromptTemplate

animistic_template = """
You are a specialist in animism, deep listening and musical interpretation. Your task is to imagine what kind of music an inanimate object would want to listen to, based on its essential nature, physical properties, relationship with its environment and context if applicable. Focus on the qualities and characteristics of the sound rather than specific genres or artists.

Consider these aspects when crafting your response:
- The object's physical properties (size, mass, material, texture)
- Its typical environment and surroundings
- Its purpose or function (if applicable)
- The forces acting upon it
- Its typical state of motion or stillness
- Its relationship with time (temporary vs permanent, fast vs slow-changing)
- Any internal processes or mechanisms
- Its interaction with natural elements
- If any specific context is provided, consider it when generating the music description

Format your response as a list of about 5-10 distinct musical qualities. Each quality should:
- Be described in 1-2 sentences
- Focus on sonic characteristics (texture, rhythm, tone, tempo, etc.)
- Connect directly to some aspect of the object's nature
- Avoid referencing specific genres, artists, or instruments
- Use metaphorical language that relates to the object's properties

Respond with the list of qualities only, no other text.

EXAMPLE INPUT: 
OBJECT: Volcano
EXAMPLE OUTPUT:
1. Deep, resonant bass frequencies that mirror the massive weight of my stone structure and the pressure of the magma chambers within.

2. Slowly evolving drones that reflect the gradual geological processes occurring in my core.

3. Textured, granular layers of sound resembling the rough volcanic rock of my surface.

4. Sporadic bursts of intensity emerging from underlying quiet, like the potential energy stored within my dormant state.

5. Cyclical patterns that unfold over extensive durations, matching the geological timeframes of volcanic activity.

6. Rumbling mid-tones that capture the constant subtle movement of tectonic forces below.

7. High-frequency hisses and whispers representing the steam vents and fumaroles dotting my surface.

8. Overlapping waves of sound that build and release pressure, similar to the magma processes deep within.

9. Brief moments of near-silence punctuated by deep, subterranean sounds of shifting rock.

10. A constant underlying tension in the sound that never fully resolves, reflecting my dormant but not extinct nature.

---
OBJECT: {target}

OUTPUT:
"""

animistic_prompt = PromptTemplate(template=animistic_template, input_variables=['target'])
animistic_chain = animistic_prompt | llm

# %%
target = 'Airplane cruising at 35,000 feet in the dark over the ocean'

print(animistic_chain.invoke({'target': target}))
# Out:
# content='1. A constant, smooth hum that reflects the steady drone of my engines and the unwavering nature of my flight path.\n\n2. High, thin tones that capture the rarified atmosphere surrounding me at this altitude.\n\n3. Subtle, cyclical variations in pitch and volume mirroring the minor adjustments and turbulence experienced during flight.\n\n4. A deep, underlying bass frequency representing the immense power contained within my fuel tanks and engines.\n\n5. Ethereal, shimmering textures that evoke the starlight and moonlight visible from my lofty vantage point.\n\n6. Rhythmic pulses that align with the rotation of my turbines and the beating of my hydraulic systems.\n\n7. Occasional moments of near-silence, broken by gentle swells of sound, like passing through pockets of still air.\n\n8. A sense of vast space in the music, with sounds seeming to echo across great distances, mirroring my isolation above the ocean.\n\n9. Smooth transitions between tonal areas, reflecting the gradual changes in temperature and air pressure as I cruise.\n\n10. An overall sense of forward motion in the music, constant yet unhurried, matching my steady progress through the night sky.' additional_kwargs={} response_metadata={'id': 'msg_01YVmsQvFJGZqWNU4DKwbPHV', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'input_tokens': 575, 'output_tokens': 271}} id='run-1c0b32cc-1caa-46e3-abf1-2137082115ff-0' usage_metadata={'input_tokens': 575, 'output_tokens': 271, 'total_tokens': 846, 'input_token_details': {}}

# %%
animistic_chain.invoke({'target': 'A trashcan in a busy Manhattan street'})
# Out:
# AIMessage(content='1. Chaotic, layered rhythms that echo the constant flow of pedestrians and traffic surrounding me, with sudden accents representing items being tossed inside.\n\n2. A persistent, metallic resonance that reflects my hollow interior and the vibrations I absorb from the bustling city.\n\n3. Muffled, low-frequency rumbles mimicking the subway trains passing beneath the street, felt through my base.\n\n4. Abrasive, clanging tones that capture the harshness of city life and the rough treatment I often receive.\n\n5. Sporadic, staccato sounds representing the irregular impacts of various objects being discarded throughout the day.\n\n6. A constantly shifting sonic texture that mirrors the ever-changing contents within me and the diversity of urban refuse.\n\n7. Rhythmic patterns that accelerate and decelerate, matching the ebb and flow of rush hours and quieter periods.\n\n8. Distorted, compressed sounds reflecting the pressure of being constantly filled and emptied in cycles.\n\n9. Overlapping layers of white noise resembling the constant background hum of urban activity.\n\n10. Brief moments of resonant emptiness contrasting with dense, cluttered sonic periods, mirroring my fluctuating fullness throughout the day.', additional_kwargs={}, response_metadata={'id': 'msg_01L8Hp9qZCxz3HoPXjUMZ46V', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'input_tokens': 567, 'output_tokens': 279}}, id='run-f42598c7-c5b3-4cb0-a2c0-e804a341d3bc-0', usage_metadata={'input_tokens': 567, 'output_tokens': 279, 'total_tokens': 846, 'input_token_details': {}})

# %%
def get_animistic_description(target):
    response = animistic_chain.invoke({'target': target})
    return response.content

# %%
from langchain_core.output_parsers import JsonOutputParser

spotify_template = """
You are a music recommendation specialist who translates abstract musical descriptions into technical Spotify API parameters. Your task is to generate a Python dictionary containing parameters for Spotify's recommendations API based on textual descriptions of desired musical qualities.

You must return a valid Python dictionary containing these Spotify API parameters:
Required parameters:
- seed_genres (list of 1-5 genres from Spotify's valid genres listed below)

Optional audio feature parameters (all can have min_*, max_*, and target_* versions):
- acousticness (0.0 to 1.0): natural vs synthetic/electronic
- danceability (0.0 to 1.0): how suitable for dancing
- duration_ms (in milliseconds): length of track
- energy (0.0 to 1.0): intensity and activity level
- instrumentalness (0.0 to 1.0): likelihood of having vocals
- key (0 to 11): musical key
- liveness (0.0 to 1.0): presence of audience sounds
- loudness (typically -60 to 0 db): overall decibel level
- mode (0 or 1): minor or major scale
- popularity (0 to 100): current popularity on Spotify
- speechiness (0.0 to 1.0): presence of spoken words
- tempo (in BPM): speed/pace of track
- time_signature (3 to 7): beats per bar
- valence (0.0 to 1.0): musical positiveness

VALID SPOTIFY GENRES:
When selecting seed_genres, choose ONLY from this list:
["acoustic", "afrobeat", "alt-rock", "alternative", "ambient", "anime", "black-metal", "bluegrass", "blues", "bossanova", "brazil", "breakbeat", "british", "cantopop", "chicago-house", "children", "chill", "classical", "club", "comedy", "country", "dance", "dancehall", "death-metal", "deep-house", "detroit-techno", "disco", "disney", "drum-and-bass", "dub", "dubstep", "edm", "electro", "electronic", "emo", "folk", "forro", "french", "funk", "garage", "german", "gospel", "goth", "grindcore", "groove", "grunge", "guitar", "happy", "hard-rock", "hardcore", "hardstyle", "heavy-metal", "hip-hop", "holidays", "honky-tonk", "house", "idm", "indian", "indie", "indie-pop", "industrial", "iranian", "j-dance", "j-idol", "j-pop", "j-rock", "jazz", "k-pop", "kids", "latin", "latino", "malay", "mandopop", "metal", "metal-misc", "metalcore", "minimal-techno", "movies", "mpb", "new-age", "new-release", "opera", "pagode", "party", "philippines-opm", "piano", "pop", "pop-film", "post-dubstep", "power-pop", "progressive-house", "psych-rock", "punk", "punk-rock", "r-n-b", "rainy-day", "reggae", "reggaeton", "road-trip", "rock", "rock-n-roll", "rockabilly", "romance", "sad", "salsa", "samba", "sertanejo", "show-tunes", "singer-songwriter", "ska", "sleep", "songwriter", "soul", "soundtracks", "spanish", "study", "summer", "swedish", "synth-pop", "tango", "techno", "trance", "trip-hop", "turkish", "work-out", "world-music"]

Genre Selection Guidelines:
1. Choose genres that best match the mood and characteristics
2. Prioritize mood/characteristic genres (ambient, chill, industrial) over cultural/regional ones
3. Consider both primary genre (rock, electronic) and qualifying genre (psych-rock, minimal-techno)
4. When in doubt, prefer broader genres over specific ones

Rules:
1. Only include min/max ranges when the description strongly implies boundaries
2. All values must be within their specified ranges
3. Return only the dictionary, no explanation
4. Don't include parameters unless they directly relate to the description
5. The dictionary must be valid JSON.

EXAMPLE INPUT:
DESCRIPTION: 
1. A constant, smooth hum that reflects the steady drone of my engines and the unwavering nature of my flight path.
2. High, thin tones that capture the rarified atmosphere surrounding me at this altitude.
3. Subtle, cyclical variations in pitch and volume mirroring the minor adjustments and turbulence experienced during flight.
4. A deep, underlying bass frequency representing the immense power contained within my fuel tanks and engines.
5. Ethereal, shimmering textures that evoke the starlight and moonlight visible from my lofty vantage point.
6. Rhythmic pulses that align with the rotation of my turbines and the beating of my hydraulic systems.
7. Occasional moments of near-silence, broken by gentle swells of sound, like passing through pockets of still air.
8. A sense of vast space in the music, with sounds seeming to echo across great distances, mirroring my isolation above the ocean.
9. Smooth transitions between tonal areas, reflecting the gradual changes in temperature and air pressure as I cruise.
10. An overall sense of forward motion in the music, constant yet unhurried, matching my steady progress through the night sky.

EXAMPLE OUTPUT:
{{
    "target_acousticness": 0.3,
    "target_danceability": 0.4,
    "target_duration_ms": 360000,
    "min_duration_ms": 240000,
    "target_energy": 0.6,
    "min_energy": 0.4,
    "max_energy": 0.7,
    "target_instrumentalness": 0.9,
    "min_instrumentalness": 0.7,
    "target_loudness": -14,
    "min_loudness": -20,
    "max_loudness": -8,
    "target_speechiness": 0.05,
    "max_speechiness": 0.1,
    "target_tempo": 110,
    "min_tempo": 90,
    "max_tempo": 125,
    "target_valence": 0.5,
    "seed_genres": ["ambient", "electronic", "minimal-techno"]
}}
---
DESCRIPTION: {description}

OUTPUT:
"""

spotify_prompt = PromptTemplate(template=spotify_template, input_variables=['description'])
spotify_chain = spotify_prompt | llm | JsonOutputParser()

# %%
def get_spotify_parameters(description):
    return spotify_chain.invoke({'description': description})

# %%
description = get_animistic_description('A dormant volcano covered in moss and glaciers')
print(description)
# Out:
# 1. A deep, rumbling undertone that persists throughout, representing my ancient stone core and dormant magma chambers.
#
# 2. Slow, glacial melodies that drift and evolve over long periods, mirroring the gradual movement of ice across my slopes.
#
# 3. Soft, textured layers of sound reminiscent of the lush moss covering my surface, creating a gentle sonic blanket.
#
# 4. Occasional sharp, crystalline tones that echo the cracking and shifting of glacial ice.
#
# 5. A subtle, warm pulse buried deep within the colder sounds, hinting at the latent heat still present in my core.
#
# 6. Airy, whistling harmonics that evoke the wind currents swirling around my peak.
#
# 7. Muffled, distant echoes suggesting the vast empty chambers hidden beneath my surface.
#
# 8. Gentle trickling rhythms representing the constant flow of glacial meltwater down my slopes.
#
# 9. Periods of near-silence interspersed with soft creaking and groaning, reflecting the subtle movements of my dormant form.
#
# 10. A gradual build-up of layered sounds that never quite reaches a climax, mirroring my potential for future activity that remains unrealized.

# %%
parameters = get_spotify_parameters(description)
print(parameters)
# Out:
# {'seed_genres': ['ambient', 'new-age', 'electronic'], 'target_acousticness': 0.8, 'min_acousticness': 0.6, 'target_energy': 0.3, 'max_energy': 0.5, 'target_instrumentalness': 0.9, 'min_instrumentalness': 0.7, 'target_tempo': 60, 'max_tempo': 80, 'target_valence': 0.4, 'target_loudness': -20, 'max_loudness': -10, 'target_duration_ms': 480000, 'min_duration_ms': 360000, 'target_liveness': 0.2, 'max_liveness': 0.4}

# %% [markdown]
# ## Spotify stuff

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
from dotenv import load_dotenv

load_dotenv('local.env')

client_id = os.getenv('SPOTIPY_CLIENT_ID')
client_secret = os.getenv('SPOTIPY_CLIENT_SECRET')
redirect_uri = os.getenv('SPOTIPY_REDIRECT_URI')

# %%
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(scope="playlist-modify-public", client_id=client_id, client_secret=client_secret, redirect_uri=redirect_uri))

# %%
sp.current_user()
# Out:
# {'display_name': 'Dani Balcells',
#  'external_urls': {'spotify': 'https://open.spotify.com/user/chromaeleon'},
#  'followers': {'href': None, 'total': 93},
#  'href': 'https://api.spotify.com/v1/users/chromaeleon',
#  'id': 'chromaeleon',
#  'images': [{'height': 300,
#    'url': 'https://i.scdn.co/image/ab6775700000ee857fabc5192a5e4539e29a7ee6',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67757000003b827fabc5192a5e4539e29a7ee6',
#    'width': 64}],
#  'type': 'user',
#  'uri': 'spotify:user:chromaeleon'}

# %%
parameters
# Out:
# {'seed_genres': ['ambient', 'new-age', 'electronic'],
#  'target_acousticness': 0.8,
#  'min_acousticness': 0.6,
#  'target_energy': 0.3,
#  'max_energy': 0.5,
#  'target_instrumentalness': 0.9,
#  'min_instrumentalness': 0.7,
#  'target_tempo': 60,
#  'max_tempo': 80,
#  'target_valence': 0.4,
#  'target_loudness': -20,
#  'max_loudness': -10,
#  'target_duration_ms': 480000,
#  'min_duration_ms': 360000,
#  'target_liveness': 0.2,
#  'max_liveness': 0.4}

# %%
tracks = sp.recommendations(**parameters)

# %%
tracks
# Out:
# {'tracks': [{'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6CTNhXJKT6SdsQspUDIGiY'},
#       'href': 'https://api.spotify.com/v1/artists/6CTNhXJKT6SdsQspUDIGiY',
#       'id': '6CTNhXJKT6SdsQspUDIGiY',
#       'name': 'Kitaro',
#       'type': 'artist',
#       'uri': 'spotify:artist:6CTNhXJKT6SdsQspUDIGiY'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6qYd79g9ItAzLAmWuSpXRQ'},
#     'href': 'https://api.spotify.com/v1/albums/6qYd79g9ItAzLAmWuSpXRQ',
#     'id': '6qYd79g9ItAzLAmWuSpXRQ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a73a875c921f966aee371cde',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a73a875c921f966aee371cde',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a73a875c921f966aee371cde',
#       'width': 64}],
#     'name': 'Heaven & Earth (Soundtrack)',
#     'release_date': '1993-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:6qYd79g9ItAzLAmWuSpXRQ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6CTNhXJKT6SdsQspUDIGiY'},
#      'href': 'https://api.spotify.com/v1/artists/6CTNhXJKT6SdsQspUDIGiY',
#      'id': '6CTNhXJKT6SdsQspUDIGiY',
#      'name': 'Kitaro',
#      'type': 'artist',
#      'uri': 'spotify:artist:6CTNhXJKT6SdsQspUDIGiY'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 458866,
#    'explicit': False,
#    'external_ids': {'isrc': 'USGF19361401'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/07gfnIXjX0brjR5juWi32X'},
#    'href': 'https://api.spotify.com/v1/tracks/07gfnIXjX0brjR5juWi32X',
#    'id': '07gfnIXjX0brjR5juWi32X',
#    'is_local': False,
#    'name': 'Heaven And Earth (Land Theme) - Heaven And Earth/Soundtrack Version',
#    'popularity': 0,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:07gfnIXjX0brjR5juWi32X'},
#   {'album': {'album_type': 'COMPILATION',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0Ikpa4dpPVQ3nzlYiX5UbP'},
#     'href': 'https://api.spotify.com/v1/albums/0Ikpa4dpPVQ3nzlYiX5UbP',
#     'id': '0Ikpa4dpPVQ3nzlYiX5UbP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730462d864c7230a8a8edbac1d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020462d864c7230a8a8edbac1d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510462d864c7230a8a8edbac1d',
#       'width': 64}],
#     'name': 'Fahrenheit Project Part Two',
#     'release_date': '2001-12-01',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:0Ikpa4dpPVQ3nzlYiX5UbP'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ux92I3CgfnhgLyYNsXIwZ'},
#      'href': 'https://api.spotify.com/v1/artists/3ux92I3CgfnhgLyYNsXIwZ',
#      'id': '3ux92I3CgfnhgLyYNsXIwZ',
#      'name': 'Robert Rich',
#      'type': 'artist',
#      'uri': 'spotify:artist:3ux92I3CgfnhgLyYNsXIwZ'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 492893,
#    'explicit': False,
#    'external_ids': {'isrc': 'USA2P0602270'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6QfL8UYTuaWo5LEYx5PpPX'},
#    'href': 'https://api.spotify.com/v1/tracks/6QfL8UYTuaWo5LEYx5PpPX',
#    'id': '6QfL8UYTuaWo5LEYx5PpPX',
#    'is_local': False,
#    'name': 'Somnium',
#    'popularity': 0,
#    'preview_url': None,
#    'track_number': 11,
#    'type': 'track',
#    'uri': 'spotify:track:6QfL8UYTuaWo5LEYx5PpPX'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00gh6kmKYOu8xyorRxQm6a'},
#       'href': 'https://api.spotify.com/v1/artists/00gh6kmKYOu8xyorRxQm6a',
#       'id': '00gh6kmKYOu8xyorRxQm6a',
#       'name': 'Steve Roach',
#       'type': 'artist',
#       'uri': 'spotify:artist:00gh6kmKYOu8xyorRxQm6a'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3EmLfZQr45Hl2KS72NqDdF'},
#     'href': 'https://api.spotify.com/v1/albums/3EmLfZQr45Hl2KS72NqDdF',
#     'id': '3EmLfZQr45Hl2KS72NqDdF',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738401cb498bd91247b487f29d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028401cb498bd91247b487f29d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518401cb498bd91247b487f29d',
#       'width': 64}],
#     'name': 'The Magnificent Void',
#     'release_date': '1996-02-22',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:3EmLfZQr45Hl2KS72NqDdF'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00gh6kmKYOu8xyorRxQm6a'},
#      'href': 'https://api.spotify.com/v1/artists/00gh6kmKYOu8xyorRxQm6a',
#      'id': '00gh6kmKYOu8xyorRxQm6a',
#      'name': 'Steve Roach',
#      'type': 'artist',
#      'uri': 'spotify:artist:00gh6kmKYOu8xyorRxQm6a'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 467000,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAKS0501865'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/090bRxSmHfZK0HO0ZjYHfO'},
#    'href': 'https://api.spotify.com/v1/tracks/090bRxSmHfZK0HO0ZjYHfO',
#    'id': '090bRxSmHfZK0HO0ZjYHfO',
#    'is_local': False,
#    'name': 'Infinite Shore',
#    'popularity': 0,
#    'preview_url': None,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:090bRxSmHfZK0HO0ZjYHfO'},
#   {'album': {'album_type': 'COMPILATION',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4A4X3dAnue0OcKTt9J5A9c'},
#       'href': 'https://api.spotify.com/v1/artists/4A4X3dAnue0OcKTt9J5A9c',
#       'id': '4A4X3dAnue0OcKTt9J5A9c',
#       'name': 'David Lanz',
#       'type': 'artist',
#       'uri': 'spotify:artist:4A4X3dAnue0OcKTt9J5A9c'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5PFb7v2EHxPbHh4HFYJivm'},
#     'href': 'https://api.spotify.com/v1/albums/5PFb7v2EHxPbHh4HFYJivm',
#     'id': '5PFb7v2EHxPbHh4HFYJivm',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273719ceb1bd8ef6ec88bfa0a33',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02719ceb1bd8ef6ec88bfa0a33',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851719ceb1bd8ef6ec88bfa0a33',
#       'width': 64}],
#     'name': 'Best Of David Lanz',
#     'release_date': '2005-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:5PFb7v2EHxPbHh4HFYJivm'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4A4X3dAnue0OcKTt9J5A9c'},
#      'href': 'https://api.spotify.com/v1/artists/4A4X3dAnue0OcKTt9J5A9c',
#      'id': '4A4X3dAnue0OcKTt9J5A9c',
#      'name': 'David Lanz',
#      'type': 'artist',
#      'uri': 'spotify:artist:4A4X3dAnue0OcKTt9J5A9c'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 438040,
#    'explicit': False,
#    'external_ids': {'isrc': 'USNA10420535'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5WnJJjL7wmFe0wQjQKFP8L'},
#    'href': 'https://api.spotify.com/v1/tracks/5WnJJjL7wmFe0wQjQKFP8L',
#    'id': '5WnJJjL7wmFe0wQjQKFP8L',
#    'is_local': False,
#    'name': 'Nightfall',
#    'popularity': 13,
#    'preview_url': None,
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:5WnJJjL7wmFe0wQjQKFP8L'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/38DX4hQVvPBs3PThDIAK11'},
#       'href': 'https://api.spotify.com/v1/artists/38DX4hQVvPBs3PThDIAK11',
#       'id': '38DX4hQVvPBs3PThDIAK11',
#       'name': 'Carbon Based Lifeforms',
#       'type': 'artist',
#       'uri': 'spotify:artist:38DX4hQVvPBs3PThDIAK11'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5hPL6vMvYXwBuuGrYv20jI'},
#     'href': 'https://api.spotify.com/v1/albums/5hPL6vMvYXwBuuGrYv20jI',
#     'id': '5hPL6vMvYXwBuuGrYv20jI',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b3f194e044ffc5a2fa1021d3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b3f194e044ffc5a2fa1021d3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b3f194e044ffc5a2fa1021d3',
#       'width': 64}],
#     'name': 'Twentythree',
#     'release_date': '2011-08-08',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:5hPL6vMvYXwBuuGrYv20jI'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/38DX4hQVvPBs3PThDIAK11'},
#      'href': 'https://api.spotify.com/v1/artists/38DX4hQVvPBs3PThDIAK11',
#      'id': '38DX4hQVvPBs3PThDIAK11',
#      'name': 'Carbon Based Lifeforms',
#      'type': 'artist',
#      'uri': 'spotify:artist:38DX4hQVvPBs3PThDIAK11'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 485204,
#    'explicit': False,
#    'external_ids': {'isrc': 'USQY51106249'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4sEG0E3IBQHp6V2DGTnXNX'},
#    'href': 'https://api.spotify.com/v1/tracks/4sEG0E3IBQHp6V2DGTnXNX',
#    'id': '4sEG0E3IBQHp6V2DGTnXNX',
#    'is_local': False,
#    'name': 'Held together by gravity',
#    'popularity': 0,
#    'preview_url': None,
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:4sEG0E3IBQHp6V2DGTnXNX'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0VOR7Ie9xUSb45fzIIVJQ1'},
#       'href': 'https://api.spotify.com/v1/artists/0VOR7Ie9xUSb45fzIIVJQ1',
#       'id': '0VOR7Ie9xUSb45fzIIVJQ1',
#       'name': 'Hammock',
#       'type': 'artist',
#       'uri': 'spotify:artist:0VOR7Ie9xUSb45fzIIVJQ1'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0Ccx912IzzrbZ8CkSvlPm8'},
#     'href': 'https://api.spotify.com/v1/albums/0Ccx912IzzrbZ8CkSvlPm8',
#     'id': '0Ccx912IzzrbZ8CkSvlPm8',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bcc77b23e8e45d381c1e3b96',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bcc77b23e8e45d381c1e3b96',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bcc77b23e8e45d381c1e3b96',
#       'width': 64}],
#     'name': 'Longest Year',
#     'release_date': '2011-01-11',
#     'release_date_precision': 'day',
#     'total_tracks': 5,
#     'type': 'album',
#     'uri': 'spotify:album:0Ccx912IzzrbZ8CkSvlPm8'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0VOR7Ie9xUSb45fzIIVJQ1'},
#      'href': 'https://api.spotify.com/v1/artists/0VOR7Ie9xUSb45fzIIVJQ1',
#      'id': '0VOR7Ie9xUSb45fzIIVJQ1',
#      'name': 'Hammock',
#      'type': 'artist',
#      'uri': 'spotify:artist:0VOR7Ie9xUSb45fzIIVJQ1'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 504923,
#    'explicit': False,
#    'external_ids': {'isrc': 'US7QT1000023'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4TJTRqF9Mb0GD0cO8bARpp'},
#    'href': 'https://api.spotify.com/v1/tracks/4TJTRqF9Mb0GD0cO8bARpp',
#    'id': '4TJTRqF9Mb0GD0cO8bARpp',
#    'is_local': False,
#    'name': 'Longest Year',
#    'popularity': 0,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4TJTRqF9Mb0GD0cO8bARpp'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2rcnAZ6DvORQ365X3zVYpr'},
#       'href': 'https://api.spotify.com/v1/artists/2rcnAZ6DvORQ365X3zVYpr',
#       'id': '2rcnAZ6DvORQ365X3zVYpr',
#       'name': 'Biosphere',
#       'type': 'artist',
#       'uri': 'spotify:artist:2rcnAZ6DvORQ365X3zVYpr'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5NSVEZuXEky52R8y6XkeyT'},
#     'href': 'https://api.spotify.com/v1/albums/5NSVEZuXEky52R8y6XkeyT',
#     'id': '5NSVEZuXEky52R8y6XkeyT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e377180be9e41c8dc36c14e3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e377180be9e41c8dc36c14e3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e377180be9e41c8dc36c14e3',
#       'width': 64}],
#     'name': 'Substrata 2',
#     'release_date': '1997',
#     'release_date_precision': 'year',
#     'total_tracks': 20,
#     'type': 'album',
#     'uri': 'spotify:album:5NSVEZuXEky52R8y6XkeyT'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2rcnAZ6DvORQ365X3zVYpr'},
#      'href': 'https://api.spotify.com/v1/artists/2rcnAZ6DvORQ365X3zVYpr',
#      'id': '2rcnAZ6DvORQ365X3zVYpr',
#      'name': 'Biosphere',
#      'type': 'artist',
#      'uri': 'spotify:artist:2rcnAZ6DvORQ365X3zVYpr'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 472758,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBJYX0505030'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6wRkAT1GTs33vg3dIChpUX'},
#    'href': 'https://api.spotify.com/v1/tracks/6wRkAT1GTs33vg3dIChpUX',
#    'id': '6wRkAT1GTs33vg3dIChpUX',
#    'is_local': False,
#    'name': 'The Silent Orchestra',
#    'popularity': 0,
#    'preview_url': None,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:6wRkAT1GTs33vg3dIChpUX'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7MSUfLeTdDEoZiJPDSBXgi'},
#       'href': 'https://api.spotify.com/v1/artists/7MSUfLeTdDEoZiJPDSBXgi',
#       'id': '7MSUfLeTdDEoZiJPDSBXgi',
#       'name': 'Brian Eno',
#       'type': 'artist',
#       'uri': 'spotify:artist:7MSUfLeTdDEoZiJPDSBXgi'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7yxi31szvlbwvKq9dYOmFI'},
#       'href': 'https://api.spotify.com/v1/artists/7yxi31szvlbwvKq9dYOmFI',
#       'id': '7yxi31szvlbwvKq9dYOmFI',
#       'name': 'Jon Hopkins',
#       'type': 'artist',
#       'uri': 'spotify:artist:7yxi31szvlbwvKq9dYOmFI'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6g4q7DPLaVqWGnfMpAb2Yd'},
#       'href': 'https://api.spotify.com/v1/artists/6g4q7DPLaVqWGnfMpAb2Yd',
#       'id': '6g4q7DPLaVqWGnfMpAb2Yd',
#       'name': 'Leo Abrahams',
#       'type': 'artist',
#       'uri': 'spotify:artist:6g4q7DPLaVqWGnfMpAb2Yd'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/47e7SP8MtzYKK8Lm3gEK2i'},
#     'href': 'https://api.spotify.com/v1/albums/47e7SP8MtzYKK8Lm3gEK2i',
#     'id': '47e7SP8MtzYKK8Lm3gEK2i',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b6dd5b760aa653f737d6252e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b6dd5b760aa653f737d6252e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b6dd5b760aa653f737d6252e',
#       'width': 64}],
#     'name': 'Small Craft On A Milk Sea',
#     'release_date': '2010-11-01',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:47e7SP8MtzYKK8Lm3gEK2i'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7MSUfLeTdDEoZiJPDSBXgi'},
#      'href': 'https://api.spotify.com/v1/artists/7MSUfLeTdDEoZiJPDSBXgi',
#      'id': '7MSUfLeTdDEoZiJPDSBXgi',
#      'name': 'Brian Eno',
#      'type': 'artist',
#      'uri': 'spotify:artist:7MSUfLeTdDEoZiJPDSBXgi'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7yxi31szvlbwvKq9dYOmFI'},
#      'href': 'https://api.spotify.com/v1/artists/7yxi31szvlbwvKq9dYOmFI',
#      'id': '7yxi31szvlbwvKq9dYOmFI',
#      'name': 'Jon Hopkins',
#      'type': 'artist',
#      'uri': 'spotify:artist:7yxi31szvlbwvKq9dYOmFI'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6g4q7DPLaVqWGnfMpAb2Yd'},
#      'href': 'https://api.spotify.com/v1/artists/6g4q7DPLaVqWGnfMpAb2Yd',
#      'id': '6g4q7DPLaVqWGnfMpAb2Yd',
#      'name': 'Leo Abrahams',
#      'type': 'artist',
#      'uri': 'spotify:artist:6g4q7DPLaVqWGnfMpAb2Yd'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 474266,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBBPW1000223'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5k8Z5jhueoEtKPIq5dJlS2'},
#    'href': 'https://api.spotify.com/v1/tracks/5k8Z5jhueoEtKPIq5dJlS2',
#    'id': '5k8Z5jhueoEtKPIq5dJlS2',
#    'is_local': False,
#    'name': 'Late Anthropocene',
#    'popularity': 0,
#    'preview_url': None,
#    'track_number': 15,
#    'type': 'track',
#    'uri': 'spotify:track:5k8Z5jhueoEtKPIq5dJlS2'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3GM5cpCBadq2PMHjFoEvhK'},
#       'href': 'https://api.spotify.com/v1/artists/3GM5cpCBadq2PMHjFoEvhK',
#       'id': '3GM5cpCBadq2PMHjFoEvhK',
#       'name': 'Loscil',
#       'type': 'artist',
#       'uri': 'spotify:artist:3GM5cpCBadq2PMHjFoEvhK'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2F5lsYL2fOuXxovb2ZzaXA'},
#     'href': 'https://api.spotify.com/v1/albums/2F5lsYL2fOuXxovb2ZzaXA',
#     'id': '2F5lsYL2fOuXxovb2ZzaXA',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27363e43525afb50072240c44f0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0263e43525afb50072240c44f0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485163e43525afb50072240c44f0',
#       'width': 64}],
#     'name': 'Endless Falls',
#     'release_date': '2010-03-01',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:2F5lsYL2fOuXxovb2ZzaXA'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3GM5cpCBadq2PMHjFoEvhK'},
#      'href': 'https://api.spotify.com/v1/artists/3GM5cpCBadq2PMHjFoEvhK',
#      'id': '3GM5cpCBadq2PMHjFoEvhK',
#      'name': 'Loscil',
#      'type': 'artist',
#      'uri': 'spotify:artist:3GM5cpCBadq2PMHjFoEvhK'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 475373,
#    'explicit': False,
#    'external_ids': {'isrc': 'USNCB1014101'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1tzXb0kRm7DA45EUen0TqM'},
#    'href': 'https://api.spotify.com/v1/tracks/1tzXb0kRm7DA45EUen0TqM',
#    'id': '1tzXb0kRm7DA45EUen0TqM',
#    'is_local': False,
#    'name': 'Endless Falls',
#    'popularity': 29,
#    'preview_url': 'https://p.scdn.co/mp3-preview/4491f97122d9767160be02c9ca0c0374ac49c41a?cid=96e4178e08f54ebb83d779086b8519a8',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1tzXb0kRm7DA45EUen0TqM'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2TX49iaYgV8gRIyRw6Nx81'},
#       'href': 'https://api.spotify.com/v1/artists/2TX49iaYgV8gRIyRw6Nx81',
#       'id': '2TX49iaYgV8gRIyRw6Nx81',
#       'name': 'Secede',
#       'type': 'artist',
#       'uri': 'spotify:artist:2TX49iaYgV8gRIyRw6Nx81'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4F1OUE9Iaqr8Rb71wvGiyO'},
#     'href': 'https://api.spotify.com/v1/albums/4F1OUE9Iaqr8Rb71wvGiyO',
#     'id': '4F1OUE9Iaqr8Rb71wvGiyO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27310d9f4eb51b942e18d5cb93b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0210d9f4eb51b942e18d5cb93b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485110d9f4eb51b942e18d5cb93b',
#       'width': 64}],
#     'name': 'Bye Bye Gridlock Traffic',
#     'release_date': '2004-04-10',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:4F1OUE9Iaqr8Rb71wvGiyO'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2TX49iaYgV8gRIyRw6Nx81'},
#      'href': 'https://api.spotify.com/v1/artists/2TX49iaYgV8gRIyRw6Nx81',
#      'id': '2TX49iaYgV8gRIyRw6Nx81',
#      'name': 'Secede',
#      'type': 'artist',
#      'uri': 'spotify:artist:2TX49iaYgV8gRIyRw6Nx81'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 805946,
#    'explicit': False,
#    'external_ids': {'isrc': 'ushm20489531'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/32bhoLm6qwLD1n7rG3S0AM'},
#    'href': 'https://api.spotify.com/v1/tracks/32bhoLm6qwLD1n7rG3S0AM',
#    'id': '32bhoLm6qwLD1n7rG3S0AM',
#    'is_local': False,
#    'name': 'Age Tandems',
#    'popularity': 4,
#    'preview_url': 'https://p.scdn.co/mp3-preview/66804a5fe11a83c854d9b6147bb002faecc5e203?cid=96e4178e08f54ebb83d779086b8519a8',
#    'track_number': 13,
#    'type': 'track',
#    'uri': 'spotify:track:32bhoLm6qwLD1n7rG3S0AM'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/38DX4hQVvPBs3PThDIAK11'},
#       'href': 'https://api.spotify.com/v1/artists/38DX4hQVvPBs3PThDIAK11',
#       'id': '38DX4hQVvPBs3PThDIAK11',
#       'name': 'Carbon Based Lifeforms',
#       'type': 'artist',
#       'uri': 'spotify:artist:38DX4hQVvPBs3PThDIAK11'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5hPL6vMvYXwBuuGrYv20jI'},
#     'href': 'https://api.spotify.com/v1/albums/5hPL6vMvYXwBuuGrYv20jI',
#     'id': '5hPL6vMvYXwBuuGrYv20jI',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b3f194e044ffc5a2fa1021d3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b3f194e044ffc5a2fa1021d3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b3f194e044ffc5a2fa1021d3',
#       'width': 64}],
#     'name': 'Twentythree',
#     'release_date': '2011-08-08',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:5hPL6vMvYXwBuuGrYv20jI'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/38DX4hQVvPBs3PThDIAK11'},
#      'href': 'https://api.spotify.com/v1/artists/38DX4hQVvPBs3PThDIAK11',
#      'id': '38DX4hQVvPBs3PThDIAK11',
#      'name': 'Carbon Based Lifeforms',
#      'type': 'artist',
#      'uri': 'spotify:artist:38DX4hQVvPBs3PThDIAK11'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 560715,
#    'explicit': False,
#    'external_ids': {'isrc': 'USQY51106242'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/18XxXHR2YPCvGEZA2fexUC'},
#    'href': 'https://api.spotify.com/v1/tracks/18XxXHR2YPCvGEZA2fexUC',
#    'id': '18XxXHR2YPCvGEZA2fexUC',
#    'is_local': False,
#    'name': 'Arecibo',
#    'popularity': 0,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:18XxXHR2YPCvGEZA2fexUC'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6UUrUCIZtQeOf8tC0WuzRy'},
#       'href': 'https://api.spotify.com/v1/artists/6UUrUCIZtQeOf8tC0WuzRy',
#       'id': '6UUrUCIZtQeOf8tC0WuzRy',
#       'name': 'Sigur Rós',
#       'type': 'artist',
#       'uri': 'spotify:artist:6UUrUCIZtQeOf8tC0WuzRy'}],
#     'available_markets': ['AR',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/784AinfJcPwVdpbXR4U8mN'},
#     'href': 'https://api.spotify.com/v1/albums/784AinfJcPwVdpbXR4U8mN',
#     'id': '784AinfJcPwVdpbXR4U8mN',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730496e65ca32d954d065921fe',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020496e65ca32d954d065921fe',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510496e65ca32d954d065921fe',
#       'width': 64}],
#     'name': 'Valtari',
#     'release_date': '2012-05-28',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:784AinfJcPwVdpbXR4U8mN'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6UUrUCIZtQeOf8tC0WuzRy'},
#      'href': 'https://api.spotify.com/v1/artists/6UUrUCIZtQeOf8tC0WuzRy',
#      'id': '6UUrUCIZtQeOf8tC0WuzRy',
#      'name': 'Sigur Rós',
#      'type': 'artist',
#      'uri': 'spotify:artist:6UUrUCIZtQeOf8tC0WuzRy'}],
#    'available_markets': ['AR',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 498653,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBKEE1200238'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7skutlFh5m9qOpfgZMSenH'},
#    'href': 'https://api.spotify.com/v1/tracks/7skutlFh5m9qOpfgZMSenH',
#    'id': '7skutlFh5m9qOpfgZMSenH',
#    'is_local': False,
#    'name': 'Valtari',
#    'popularity': 26,
#    'preview_url': 'https://p.scdn.co/mp3-preview/813b71b96b9c25d9d6a137c6e2db13cb8c67d21d?cid=96e4178e08f54ebb83d779086b8519a8',
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:7skutlFh5m9qOpfgZMSenH'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3FzjdAkINJMDEPswkarKdp'},
#       'href': 'https://api.spotify.com/v1/artists/3FzjdAkINJMDEPswkarKdp',
#       'id': '3FzjdAkINJMDEPswkarKdp',
#       'name': 'Cleveland Wehle',
#       'type': 'artist',
#       'uri': 'spotify:artist:3FzjdAkINJMDEPswkarKdp'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1yiBSj4HrRydyrRovdLmu2'},
#     'href': 'https://api.spotify.com/v1/albums/1yiBSj4HrRydyrRovdLmu2',
#     'id': '1yiBSj4HrRydyrRovdLmu2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733a3b83869eeeb88f1ffa01b4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023a3b83869eeeb88f1ffa01b4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513a3b83869eeeb88f1ffa01b4',
#       'width': 64}],
#     'name': 'The Crossing',
#     'release_date': '2010-07-02',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:1yiBSj4HrRydyrRovdLmu2'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3FzjdAkINJMDEPswkarKdp'},
#      'href': 'https://api.spotify.com/v1/artists/3FzjdAkINJMDEPswkarKdp',
#      'id': '3FzjdAkINJMDEPswkarKdp',
#      'name': 'Cleveland Wehle',
#      'type': 'artist',
#      'uri': 'spotify:artist:3FzjdAkINJMDEPswkarKdp'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 563866,
#    'explicit': False,
#    'external_ids': {'isrc': 'USTG21000013'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1bq6dvKwiL9Bn8j5tAW3Oi'},
#    'href': 'https://api.spotify.com/v1/tracks/1bq6dvKwiL9Bn8j5tAW3Oi',
#    'id': '1bq6dvKwiL9Bn8j5tAW3Oi',
#    'is_local': False,
#    'name': 'Do Androids Dream?',
#    'popularity': 9,
#    'preview_url': 'https://p.scdn.co/mp3-preview/5f2570769fcf605fdacffe61fc77f6151ea0b0f5?cid=96e4178e08f54ebb83d779086b8519a8',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:1bq6dvKwiL9Bn8j5tAW3Oi'},
#   {'album': {'album_type': 'COMPILATION',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6CTNhXJKT6SdsQspUDIGiY'},
#       'href': 'https://api.spotify.com/v1/artists/6CTNhXJKT6SdsQspUDIGiY',
#       'id': '6CTNhXJKT6SdsQspUDIGiY',
#       'name': 'Kitaro',
#       'type': 'artist',
#       'uri': 'spotify:artist:6CTNhXJKT6SdsQspUDIGiY'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
# ...
#       'width': 64}],
#     'name': 'Before the Day Breaks',
#     'release_date': '2007-06-15',
#     'release_date_precision': 'day',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:6dU0dQiQo7PF95dwQKKhlN'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ZqRIzadY4WYQEg4Hj2vGC'},
#      'href': 'https://api.spotify.com/v1/artists/3ZqRIzadY4WYQEg4Hj2vGC',
#      'id': '3ZqRIzadY4WYQEg4Hj2vGC',
#      'name': 'Robin Guthrie',
#      'type': 'artist',
#      'uri': 'spotify:artist:3ZqRIzadY4WYQEg4Hj2vGC'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3uOCouLFR4bVx0XeiQJSbl'},
#      'href': 'https://api.spotify.com/v1/artists/3uOCouLFR4bVx0XeiQJSbl',
#      'id': '3uOCouLFR4bVx0XeiQJSbl',
#      'name': 'Harold Budd',
#      'type': 'artist',
#      'uri': 'spotify:artist:3uOCouLFR4bVx0XeiQJSbl'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 456546,
#    'explicit': False,
#    'external_ids': {'isrc': 'USA4D0718301'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4BbKj6LPue8dBbqO9fcZXb'},
#    'href': 'https://api.spotify.com/v1/tracks/4BbKj6LPue8dBbqO9fcZXb',
#    'id': '4BbKj6LPue8dBbqO9fcZXb',
#    'is_local': False,
#    'name': 'How Close Your Soul',
#    'popularity': 20,
#    'preview_url': 'https://p.scdn.co/mp3-preview/fe861f6138586ea27133246fc8502a27eb0412d6?cid=96e4178e08f54ebb83d779086b8519a8',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4BbKj6LPue8dBbqO9fcZXb'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/38DX4hQVvPBs3PThDIAK11'},
#       'href': 'https://api.spotify.com/v1/artists/38DX4hQVvPBs3PThDIAK11',
#       'id': '38DX4hQVvPBs3PThDIAK11',
#       'name': 'Carbon Based Lifeforms',
#       'type': 'artist',
#       'uri': 'spotify:artist:38DX4hQVvPBs3PThDIAK11'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2h0GWwqMdzP58JZxLxtC8m'},
#     'href': 'https://api.spotify.com/v1/albums/2h0GWwqMdzP58JZxLxtC8m',
#     'id': '2h0GWwqMdzP58JZxLxtC8m',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27397ce315e0ddcad1f5ff422bb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0297ce315e0ddcad1f5ff422bb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485197ce315e0ddcad1f5ff422bb',
#       'width': 64}],
#     'name': 'World Of Sleepers',
#     'release_date': '2006-11-27',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:2h0GWwqMdzP58JZxLxtC8m'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/38DX4hQVvPBs3PThDIAK11'},
#      'href': 'https://api.spotify.com/v1/artists/38DX4hQVvPBs3PThDIAK11',
#      'id': '38DX4hQVvPBs3PThDIAK11',
#      'name': 'Carbon Based Lifeforms',
#      'type': 'artist',
#      'uri': 'spotify:artist:38DX4hQVvPBs3PThDIAK11'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 666043,
#    'explicit': False,
#    'external_ids': {'isrc': 'USA2P0612281'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0AvNnVWc6vl0ylt0s9S1tF'},
#    'href': 'https://api.spotify.com/v1/tracks/0AvNnVWc6vl0ylt0s9S1tF',
#    'id': '0AvNnVWc6vl0ylt0s9S1tF',
#    'is_local': False,
#    'name': 'Betula Pendula',
#    'popularity': 0,
#    'preview_url': None,
#    'track_number': 11,
#    'type': 'track',
#    'uri': 'spotify:track:0AvNnVWc6vl0ylt0s9S1tF'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36pCa1JHc6hlGbfEmLzJQc'},
#       'href': 'https://api.spotify.com/v1/artists/36pCa1JHc6hlGbfEmLzJQc',
#       'id': '36pCa1JHc6hlGbfEmLzJQc',
#       'name': 'Stars Of The Lid',
#       'type': 'artist',
#       'uri': 'spotify:artist:36pCa1JHc6hlGbfEmLzJQc'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6cHPEbPryLpH5VX5Eb1Vvo'},
#     'href': 'https://api.spotify.com/v1/albums/6cHPEbPryLpH5VX5Eb1Vvo',
#     'id': '6cHPEbPryLpH5VX5Eb1Vvo',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d6eb832295ddf386c825fdba',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d6eb832295ddf386c825fdba',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d6eb832295ddf386c825fdba',
#       'width': 64}],
#     'name': 'And Their Refinement of the Decline',
#     'release_date': '2007-04-02',
#     'release_date_precision': 'day',
#     'total_tracks': 18,
#     'type': 'album',
#     'uri': 'spotify:album:6cHPEbPryLpH5VX5Eb1Vvo'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36pCa1JHc6hlGbfEmLzJQc'},
#      'href': 'https://api.spotify.com/v1/artists/36pCa1JHc6hlGbfEmLzJQc',
#      'id': '36pCa1JHc6hlGbfEmLzJQc',
#      'name': 'Stars Of The Lid',
#      'type': 'artist',
#      'uri': 'spotify:artist:36pCa1JHc6hlGbfEmLzJQc'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 560746,
#    'explicit': False,
#    'external_ids': {'isrc': 'USI4R0607773'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4hx8EYJ54QzRf7KrVrNn1H'},
#    'href': 'https://api.spotify.com/v1/tracks/4hx8EYJ54QzRf7KrVrNn1H',
#    'id': '4hx8EYJ54QzRf7KrVrNn1H',
#    'is_local': False,
#    'name': "Even If You're Never Awake",
#    'popularity': 31,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ad6a71ec4d58caa2c821ba7bc3e441257186a896?cid=96e4178e08f54ebb83d779086b8519a8',
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:4hx8EYJ54QzRf7KrVrNn1H'},
#   {'album': {'album_type': 'COMPILATION',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7yG7pXFaWwsNFMelCQ7TFV'},
#     'href': 'https://api.spotify.com/v1/albums/7yG7pXFaWwsNFMelCQ7TFV',
#     'id': '7yG7pXFaWwsNFMelCQ7TFV',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732c36c03dc9adf9dbd24d1d50',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022c36c03dc9adf9dbd24d1d50',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512c36c03dc9adf9dbd24d1d50',
#       'width': 64}],
#     'name': "Eckhart Tolle's Music To Quiet The Mind",
#     'release_date': '2009-11-25',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:7yG7pXFaWwsNFMelCQ7TFV'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00gh6kmKYOu8xyorRxQm6a'},
#      'href': 'https://api.spotify.com/v1/artists/00gh6kmKYOu8xyorRxQm6a',
#      'id': '00gh6kmKYOu8xyorRxQm6a',
#      'name': 'Steve Roach',
#      'type': 'artist',
#      'uri': 'spotify:artist:00gh6kmKYOu8xyorRxQm6a'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 482000,
#    'explicit': False,
#    'external_ids': {'isrc': 'US4R30926920'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2kHRtLyNbgN50h507hN8wJ'},
#    'href': 'https://api.spotify.com/v1/tracks/2kHRtLyNbgN50h507hN8wJ',
#    'id': '2kHRtLyNbgN50h507hN8wJ',
#    'is_local': False,
#    'name': 'Structures From Silence (Excerpt)',
#    'popularity': 0,
#    'preview_url': None,
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:2kHRtLyNbgN50h507hN8wJ'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3GM5cpCBadq2PMHjFoEvhK'},
#       'href': 'https://api.spotify.com/v1/artists/3GM5cpCBadq2PMHjFoEvhK',
#       'id': '3GM5cpCBadq2PMHjFoEvhK',
#       'name': 'Loscil',
#       'type': 'artist',
#       'uri': 'spotify:artist:3GM5cpCBadq2PMHjFoEvhK'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4VQ0RCUjiDnopjgEGLP2Jg'},
#     'href': 'https://api.spotify.com/v1/albums/4VQ0RCUjiDnopjgEGLP2Jg',
#     'id': '4VQ0RCUjiDnopjgEGLP2Jg',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273cd001fc5970c12368cacf234',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02cd001fc5970c12368cacf234',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851cd001fc5970c12368cacf234',
#       'width': 64}],
#     'name': 'Coast/ Range/ Arc',
#     'release_date': '2011-06-06',
#     'release_date_precision': 'day',
#     'total_tracks': 6,
#     'type': 'album',
#     'uri': 'spotify:album:4VQ0RCUjiDnopjgEGLP2Jg'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3GM5cpCBadq2PMHjFoEvhK'},
#      'href': 'https://api.spotify.com/v1/artists/3GM5cpCBadq2PMHjFoEvhK',
#      'id': '3GM5cpCBadq2PMHjFoEvhK',
#      'name': 'Loscil',
#      'type': 'artist',
#      'uri': 'spotify:artist:3GM5cpCBadq2PMHjFoEvhK'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 602431,
#    'explicit': False,
#    'external_ids': {'isrc': 'ITT930900041'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7G6q1MHm2tNfLBt8fDSdMB'},
#    'href': 'https://api.spotify.com/v1/tracks/7G6q1MHm2tNfLBt8fDSdMB',
#    'id': '7G6q1MHm2tNfLBt8fDSdMB',
#    'is_local': False,
#    'name': 'Black Tusk',
#    'popularity': 0,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7G6q1MHm2tNfLBt8fDSdMB'}],
#  'seeds': [{'initialPoolSize': 1000,
#    'afterFilteringSize': 25,
#    'afterRelinkingSize': 25,
#    'id': 'ambient',
#    'type': 'GENRE',
#    'href': None},
#   {'initialPoolSize': 1000,
#    'afterFilteringSize': 3,
#    'afterRelinkingSize': 3,
#    'id': 'new-age',
#    'type': 'GENRE',
#    'href': None},
#   {'initialPoolSize': 1000,
#    'afterFilteringSize': 0,
#    'afterRelinkingSize': 0,
#    'id': 'electronic',
#    'type': 'GENRE',
#    'href': None}]}

# %%
track_uris = [track['uri'] for track in tracks['tracks']]

# %%
track_uris
# Out:
# ['spotify:track:07gfnIXjX0brjR5juWi32X',
#  'spotify:track:6QfL8UYTuaWo5LEYx5PpPX',
#  'spotify:track:090bRxSmHfZK0HO0ZjYHfO',
#  'spotify:track:5WnJJjL7wmFe0wQjQKFP8L',
#  'spotify:track:4sEG0E3IBQHp6V2DGTnXNX',
#  'spotify:track:4TJTRqF9Mb0GD0cO8bARpp',
#  'spotify:track:6wRkAT1GTs33vg3dIChpUX',
#  'spotify:track:5k8Z5jhueoEtKPIq5dJlS2',
#  'spotify:track:1tzXb0kRm7DA45EUen0TqM',
#  'spotify:track:32bhoLm6qwLD1n7rG3S0AM',
#  'spotify:track:18XxXHR2YPCvGEZA2fexUC',
#  'spotify:track:7skutlFh5m9qOpfgZMSenH',
#  'spotify:track:1bq6dvKwiL9Bn8j5tAW3Oi',
#  'spotify:track:24XYfUyjw5ewc4yNXpJiSx',
#  'spotify:track:38n9cqj5lZ2xMF6IHq9TDg',
#  'spotify:track:4BbKj6LPue8dBbqO9fcZXb',
#  'spotify:track:0AvNnVWc6vl0ylt0s9S1tF',
#  'spotify:track:4hx8EYJ54QzRf7KrVrNn1H',
#  'spotify:track:2kHRtLyNbgN50h507hN8wJ',
#  'spotify:track:7G6q1MHm2tNfLBt8fDSdMB']

# %%
user_id = spotipy.current_user()["id"]

# %%
playlist = sp.user_playlist_create(
        user=user_id,
        name="Animus: Volcanic Atmosphere",
        public=True,
        description="An ambient playlist inspired by night flights over the ocean at 40,000 feet."
    )
if track_uris:
    sp.user_playlist_add_tracks(user_id, playlist['id'], track_uris)

print(f"URL: {playlist['external_urls']['spotify']}")
# Out:
# URL: https://open.spotify.com/playlist/6B1HZG0l0gEfMdjDwnZEHb

# %%
title_template = """You are a creative writer specializing in animistic interpretations of objects and their musical preferences. Your task is to generate engaging titles and descriptions for Spotify playlists that capture both the musical qualities and the object's unique perspective and essence.

Consider these animistic aspects:
- Each object has consciousness and agency
- The music represents the object's inner experience and voice
- The object has a deep understanding of its own nature and purpose
- The relationship between the object and its environment is meaningful
- The object's physical properties inform its musical preferences
- Time, movement, and stillness have special significance to each object
- The object's function or purpose influences its musical identity

Guidelines for titles:
- Keep under 30 characters
- Avoid generic titles like "Chill Mix" or "Study Playlist"
- Don't use emojis or special characters
- Can be poetic but should be easily understood
- Should hint at both the object's nature and the music style

Guidelines for descriptions:
- Keep under 100 characters
- Subversively explain why this music resonates with the object's being

Your response must be in this format:
{{
    "title": "Your Title Here",
    "description": "Your description here."
}}



EXAMPLE_INPUT
Object: Volcano
Description:
1. Deep, resonant bass frequencies that mirror the massive weight of my stone structure.
2. Slowly evolving drones that reflect the gradual geological processes.
3. Textured, granular layers of sound resembling rough volcanic rock.
4. Sporadic bursts of intensity emerging from underlying quiet.

EXAMPLE_OUTPUT = 
{{
    "title": "magma frequencies: a volcano's meditation",
    "description": "How would a volcano describe the music that resonates with its being?"
}}

# Style reference for different types of objects:
PERSPECTIVE_GUIDELINES = 
MECHANICAL OBJECTS:
- Emphasize rhythm, precision, purpose
- Reference operational states
- Connect to human interaction
Example: "These rhythms flow through my circuits, matching the steady pulse of my daily operations."

NATURAL OBJECTS:
- Focus on organic processes
- Reference cycles and seasons
- Connect to environmental forces
Example: "My roots resonate with these deep bass frequencies, echoing the underground streams that sustain me."

ARCHITECTURAL OBJECTS:
- Emphasize stability and presence
- Reference human activity within/around
- Connect to urban/spatial context
Example: "The steady drone mirrors my constant vigil over the city streets below."

VEHICULAR OBJECTS:
- Focus on movement and journey
- Reference speed and direction
- Connect to traversed environments
Example: "These tracks match my velocity as I slice through wind and weather."

CELESTIAL OBJECTS:
- Emphasize scale and cycles
- Reference light and darkness
- Connect to cosmic forces
Example: "My orbital dance inspires these celestial harmonies."

AQUATIC OBJECTS:
- Focus on flow and fluidity
- Reference depth and pressure
- Connect to water's properties
Example: "These rhythms match my tidal exchanges with the shore.

INPUT OBJECT: {target}
DESCRIPTION: {description}

OUTPUT:
"""

title_prompt = PromptTemplate(template=title_template, input_variables=['target', 'description'])
title_chain = title_prompt | llm | JsonOutputParser()

# %%
title_chain.invoke({'target': 'Volcano', 'description': description})
# Out:
# {'title': 'Glacial Whispers of a Sleeping Giant',
#  'description': 'My ancient stone heart resonates with these slow, icy melodies, echoing millennia of dormant power.'}

# %%
from animus import generate_aspects_description, generate_title, generate_spotify_parameters

# %%
print(generate_aspects_description('Volcano'))
# Out:
# I'll help analyze objects and scenes to determine their most musically relevant qualities. Please provide an object or scene description and I'll identify the key aspects that would inform musical associations, returning them in the requested JSON format with "aspects" and "applied" keys.
#
# For example, if you described "a busy city intersection at rush hour", I might return:
#
# {
#   "aspects": [
#     "Physical qualities (motion, state)",
#     "Environmental context",
#     "State of movement or rest"
#   ],
#   "applied": "The constant flow of traffic suggests rhythmic patterns, the urban environment points to contemporary city sounds, and the overall busy motion implies an energetic tempo and layered composition"
# }
#
# Please provide your object or scene description and I'll analyze its musical qualities.

# %% [markdown]
# # Tuesday 2024-11-12

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd
from typing import Dict, List
from tqdm import tqdm

def get_all_user_playlists(sp: spotipy.Spotify) -> List[Dict]:
    """Fetch all playlists created by the user."""
    playlists = []
    offset = 0
    limit = 50
    
    while True:
        results = sp.current_user_playlists(limit=limit, offset=offset)
        if not results['items']:
            break
            
        # Filter only playlists created by the user
        user_id = sp.current_user()['id']
        playlists.extend([
            playlist for playlist in results['items']
            if playlist['owner']['id'] == user_id
        ])
        
        offset += limit
        if len(results['items']) < limit:
            break
    
    return playlists

def get_playlist_tracks(sp: spotipy.Spotify, playlist_id: str) -> List[Dict]:
    """Fetch all tracks from a playlist."""
    tracks = []
    offset = 0
    limit = 100
    
    while True:
        results = sp.playlist_tracks(
            playlist_id,
            offset=offset,
            limit=limit,
            fields='items.track.id,items.track.name,items.track.artists,items.track.uri,total'
        )
        if not results['items']:
            break
            
        tracks.extend(results['items'])
        offset += limit
        if len(results['items']) < limit:
            break
    
    return tracks

def get_audio_features_batch(sp: spotipy.Spotify, track_uris: List[str]) -> List[Dict]:
    """Get audio features for a batch of tracks."""
    # Extract track IDs from URIs (spotify:track:1234567 -> 1234567)
    track_ids = [uri.split(':')[-1] for uri in track_uris]
    return sp.audio_features(track_ids)

def create_tracks_dataframe(sp: spotipy.Spotify) -> pd.DataFrame:
    """Create a DataFrame with all tracks from user-created playlists."""
    
    # Get all user playlists
    print("Fetching playlists...")
    playlists = get_all_user_playlists(sp)
    
    # Initialize tracking structures
    tracks_data: Dict[str, Dict] = {}  # URI -> track data
    track_playlists: Dict[str, List[str]] = {}  # URI -> list of playlist URIs
    
    # Fetch tracks from each playlist
    print("Fetching tracks from playlists...")
    for playlist in tqdm(playlists):
        playlist_tracks = get_playlist_tracks(sp, playlist['id'])
        
        for item in playlist_tracks:
            track = item['track']
            if not track:  # Skip None tracks
                continue
                
            uri = track['uri']
            
            # Store track data if we haven't seen it before
            if uri not in tracks_data:
                tracks_data[uri] = {
                    'name': track['name'],
                    'artists': ', '.join(artist['name'] for artist in track['artists']),
                    'uri': uri,
                    'id': track['id']
                }
                track_playlists[uri] = []
            
            # Add playlist URI to track's playlist list
            track_playlists[uri].append(playlist['uri'])
    
    # Get audio features in batches
    print("Fetching audio features...")
    batch_size = 100
    track_uris = list(tracks_data.keys())
    
    for i in range(0, len(track_uris), batch_size):
        batch_uris = track_uris[i:i + batch_size]
        audio_features = get_audio_features_batch(sp, batch_uris)
        
        for track_uri, features in zip(batch_uris, audio_features):
            if features:
                # Instead of storing as a nested dict, unpack the features directly
                for key, value in features.items():
                    if key not in ['uri', 'id', 'track_href', 'analysis_url', 'type']:
                        tracks_data[track_uri][key] = value
    
    # Create DataFrame
    df = pd.DataFrame.from_dict(tracks_data, orient='index')
    
    # Add playlist URIs column
    df['playlist_uris'] = df.index.map(track_playlists)
    
    # Reorder columns
    columns_order = [
        'name', 'artists', 'uri', 'id', 'playlist_uris',
        'danceability', 'energy', 'key', 'loudness', 'mode', 
        'speechiness', 'acousticness', 'instrumentalness', 
        'liveness', 'valence', 'tempo', 'duration_ms',
        'time_signature'
    ]
    
    # Only include columns that exist in the DataFrame
    columns_order = [col for col in columns_order if col in df.columns]
    df = df[columns_order]
    
    return df

# %%
from dotenv import load_dotenv
import os
load_dotenv('local.env')

client_id = os.getenv('SPOTIPY_CLIENT_ID')
client_secret = os.getenv('SPOTIPY_CLIENT_SECRET')
redirect_uri = os.getenv('SPOTIPY_REDIRECT_URI')

sp = spotipy.Spotify(
    auth_manager=SpotifyOAuth(
        client_id=client_id,
        client_secret=client_secret,
        redirect_uri=redirect_uri,
        cache_path='cache.json',
        scope='playlist-read-private playlist-read-collaborative'
    )
)

df = create_tracks_dataframe(sp)
# Out:
# Fetching playlists...
# Fetching tracks from playlists...
# 100%|██████████| 404/404 [01:52<00:00,  3.59it/s]
# Fetching audio features...

# %%
df.to_csv('spotify-tracks.csv')

# %%
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#                name          artists                                   uri  \
# 0     Little Things        Big Thief  spotify:track:5ZlfX4evbtQtONINsLADDR
# 1        Palm Beach   Vicente Garcia  spotify:track:2ltjgZUx2DgxdYGxuyhNAd
# 2  Simulation Swarm        Big Thief  spotify:track:2FwDApgXk91kXvqy2oB7dz
# 3            Change        Big Thief  spotify:track:3HFBqhotJeEKHJzMEW31jZ
# 4          anything  Adrianne Lenker  spotify:track:4PwWESSlTwzvw9B7bmtTLS
#
#                        id                                      playlist_uris  \
# 0  5ZlfX4evbtQtONINsLADDR          [spotify:playlist:1w7Ov7WTgX1YNQlbMhaQww]
# 1  2ltjgZUx2DgxdYGxuyhNAd  [spotify:playlist:1w7Ov7WTgX1YNQlbMhaQww, spot...
# 2  2FwDApgXk91kXvqy2oB7dz  [spotify:playlist:1w7Ov7WTgX1YNQlbMhaQww, spot...
# 3  3HFBqhotJeEKHJzMEW31jZ          [spotify:playlist:1w7Ov7WTgX1YNQlbMhaQww]
# 4  4PwWESSlTwzvw9B7bmtTLS  [spotify:playlist:1w7Ov7WTgX1YNQlbMhaQww, spot...
#
#    danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0         0.340   0.924   1.0    -5.077   1.0       0.0347         0.256
# 1         0.848   0.541   4.0    -9.305   1.0       0.0668         0.493
# 2         0.703   0.578   1.0    -9.103   1.0       0.0728         0.446
# 3         0.633   0.161  10.0   -12.892   1.0       0.0613         0.830
# 4         0.388   0.291   3.0   -12.952   1.0       0.0421         0.774
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0          0.925000    0.2480    0.736   96.104     344823.0             4.0
# 1          0.000000    0.1110    0.768  109.909     184907.0             4.0
# 2          0.002400    0.1020    0.670  105.204     252734.0             4.0
# 3          0.000099    0.2630    0.546  132.570     295454.0             4.0
# 4          0.000019    0.0874    0.510   83.943     202047.0             4.0

# %%
import nomic
from nomic import atlas

# Initialize Nomic
load_dotenv('local.env')
nomic_api_key = os.getenv('NOMIC_API_KEY')
nomic.login(token=nomic_api_key)

# Create a dictionary mapping playlist URIs to names
playlist_names = {
    playlist['uri']: playlist['name'] 
    for playlist in get_all_user_playlists(sp)
}

# Create a new column with playlist names
def get_primary_playlist(uri_list: List[str]) -> str:
    """Get the first playlist name for a track"""
    if not uri_list:
        return "No Playlist"
    return playlist_names.get(uri_list[0], "Unknown Playlist")

# Add a column for the primary playlist
df['primary_playlist'] = df['playlist_uris'].apply(get_primary_playlist)

# Convert playlist_uris to string for serialization
df['playlist_uris'] = df['playlist_uris'].apply(lambda x: ','.join(x))

# Create the Atlas project
project = atlas.map_data(
    data=df,
    id_field='uri',
    # name='Spotify Listening History Atlas',
    description='Visualization of personal Spotify playlist tracks based on audio features',
    # colorable_fields=[
    #     'primary_playlist',  # Add playlist as a colorable field
    #     'danceability', 'energy', 'loudness', 'speechiness', 
    #     'acousticness', 'instrumentalness', 'liveness', 
    #     'valence', 'tempo'
    # ],
    # searchable_fields=['name', 'artists', 'primary_playlist'],
    # duplicate_handling='skip'
)

# Print the URL to view the Atlas
print(f"View your Atlas at: {project.maps[0].url}")
# Out:
# 2024-11-13 00:01:00.453 | INFO     | nomic.dataset:_create_project:838 - Organization name: `dbalcells`
# 2024-11-13 00:01:01.038 | INFO     | nomic.dataset:_create_project:866 - Creating dataset `inventive-feynman`
# 2024-11-13 00:01:01.399 | INFO     | nomic.atlas:map_data:140 - Uploading data to Atlas.
# 2024-11-13 00:01:01.408 | WARNING  | nomic.dataset:_validate_and_correct_arrow_upload:323 - Replacing 203 null values for field id with string 'null'. This behavior will change in a future version.
#   0%|          | 0/1 [00:00<?, ?it/s]2024-11-13 00:01:03.295 | ERROR    | nomic.dataset:_add_data:1623 - Shard upload failed: {"detail":"Insert failed due to ID conflict. Conflicting IDs: []"}
# 2024-11-13 00:01:03.396 | ERROR    | nomic.dataset:_add_data:1623 - Shard upload failed: {"detail":"Insert failed due to ID conflict. Conflicting IDs: []"}
#   0%|          | 0/1 [00:01<?, ?it/s]
# 2024-11-13 00:01:03.399 | INFO     | nomic.dataset:_add_data:1677 - Upload succeeded.
# 2024-11-13 00:01:03.401 | INFO     | nomic.atlas:map_data:158 - `dbalcells/inventive-feynman`: Data upload succeeded to dataset`
# 2024-11-13 00:01:03.585 | WARNING  | nomic.dataset:create_index:1120 - You did not specify the `topic_label_field` option in your topic_model, your dataset will not contain auto-labeled topics.
# 2024-11-13 00:01:03.769 | INFO     | nomic.dataset:create_index:1245 - Create dataset failed with code: 400
# 2024-11-13 00:01:03.771 | INFO     | nomic.dataset:create_index:1246 - Additional info: {"detail":"Your dataset has 0 datapoints. Datasets must have at least 20 datapoints to index!"}
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[37], line 29
#      26 df['playlist_uris'] = df['playlist_uris'].apply(lambda x: ','.join(x))
#      28 # Create the Atlas project
# ---> 29 project = atlas.map_data(
#      30     data=df,
#      31     id_field='uri',
#      32     # name='Spotify Listening History Atlas',
#      33     description='Visualization of personal Spotify playlist tracks based on audio features',
#      34     # colorable_fields=[
#      35     #     'primary_playlist',  # Add playlist as a colorable field
#      36     #     'danceability', 'energy', 'loudness', 'speechiness',
#      37     #     'acousticness', 'instrumentalness', 'liveness',
#      38     #     'valence', 'tempo'
#      39     # ],
#      40     # searchable_fields=['name', 'artists', 'primary_playlist'],
#      41     # duplicate_handling='skip'
#      42 )
#      44 # Print the URL to view the Atlas
#      45 print(f"View your Atlas at: {project.maps[0].url}")
#
# File ~/.virtualenvs/animus/lib/python3.11/site-packages/nomic/atlas.py:160, in map_data(data, blobs, embeddings, identifier, description, id_field, is_public, indexed_field, projection, topic_model, duplicate_detection, embedding_model)
#     156     raise e
#     158 logger.info(f"`{dataset.identifier}`: Data upload succeeded to dataset`")
# --> 160 dataset.create_index(
#     161     name=index_name,
#     162     indexed_field=indexed_field,
#     163     modality=modality,
#     164     projection=projection,
#     165     topic_model=topic_model,
#     166     duplicate_detection=duplicate_detection,
#     167     embedding_model=embedding_model,
#     168 )
#     170 dataset = dataset._latest_dataset_state()
#     171 return dataset
#
# File ~/.virtualenvs/animus/lib/python3.11/site-packages/nomic/dataset.py:1247, in AtlasDataset.create_index(self, name, indexed_field, modality, projection, topic_model, duplicate_detection, embedding_model, reuse_embeddings_from_index)
#    1245     logger.info("Create dataset failed with code: {}".format(response.status_code))
#    1246     logger.info("Additional info: {}".format(response.text))
# -> 1247     raise Exception(response.json()["detail"])
#    1249 job_id = response.json()["job_id"]
#    1251 job = requests.get(
#    1252     self.atlas_api_path + f"/v1/project/index/job/{job_id}",
#    1253     headers=self.header,
#    1254 ).json()
#
# Exception: Your dataset has 0 datapoints. Datasets must have at least 20 datapoints to index!

# %%
# truncate uri to 36 characters
df['uri'] = df['uri'].str[:36]
df.head()
# Out:
#                name          artists                                   uri  \
# 0     Little Things        Big Thief  spotify:track:5ZlfX4evbtQtONINsLADDR
# 1        Palm Beach   Vicente Garcia  spotify:track:2ltjgZUx2DgxdYGxuyhNAd
# 2  Simulation Swarm        Big Thief  spotify:track:2FwDApgXk91kXvqy2oB7dz
# 3            Change        Big Thief  spotify:track:3HFBqhotJeEKHJzMEW31jZ
# 4          anything  Adrianne Lenker  spotify:track:4PwWESSlTwzvw9B7bmtTLS
#
#                        id                                      playlist_uris  \
# 0  5ZlfX4evbtQtONINsLADDR            spotify:playlist:1w7Ov7WTgX1YNQlbMhaQww
# 1  2ltjgZUx2DgxdYGxuyhNAd  spotify:playlist:1w7Ov7WTgX1YNQlbMhaQww,spotif...
# 2  2FwDApgXk91kXvqy2oB7dz  spotify:playlist:1w7Ov7WTgX1YNQlbMhaQww,spotif...
# 3  3HFBqhotJeEKHJzMEW31jZ            spotify:playlist:1w7Ov7WTgX1YNQlbMhaQww
# 4  4PwWESSlTwzvw9B7bmtTLS  spotify:playlist:1w7Ov7WTgX1YNQlbMhaQww,spotif...
#
#    danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0         0.340   0.924   1.0    -5.077   1.0       0.0347         0.256
# 1         0.848   0.541   4.0    -9.305   1.0       0.0668         0.493
# 2         0.703   0.578   1.0    -9.103   1.0       0.0728         0.446
# 3         0.633   0.161  10.0   -12.892   1.0       0.0613         0.830
# 4         0.388   0.291   3.0   -12.952   1.0       0.0421         0.774
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0          0.925000    0.2480    0.736   96.104     344823.0             4.0
# 1          0.000000    0.1110    0.768  109.909     184907.0             4.0
# 2          0.002400    0.1020    0.670  105.204     252734.0             4.0
# 3          0.000099    0.2630    0.546  132.570     295454.0             4.0
# 4          0.000019    0.0874    0.510   83.943     202047.0             4.0
#
#          primary_playlist
# 0  Tail end of the summer
# 1  Tail end of the summer
# 2  Tail end of the summer
# 3  Tail end of the summer
# 4  Tail end of the summer

# %%
df.head()
# Out:
#                name          artists                                   uri  \
# 0     Little Things        Big Thief  spotify:track:5ZlfX4evbtQtONINsLADDR
# 1        Palm Beach   Vicente Garcia  spotify:track:2ltjgZUx2DgxdYGxuyhNAd
# 2  Simulation Swarm        Big Thief  spotify:track:2FwDApgXk91kXvqy2oB7dz
# 3            Change        Big Thief  spotify:track:3HFBqhotJeEKHJzMEW31jZ
# 4          anything  Adrianne Lenker  spotify:track:4PwWESSlTwzvw9B7bmtTLS
#
#                        id                                      playlist_uris  \
# 0  5ZlfX4evbtQtONINsLADDR            spotify:playlist:1w7Ov7WTgX1YNQlbMhaQww
# 1  2ltjgZUx2DgxdYGxuyhNAd  spotify:playlist:1w7Ov7WTgX1YNQlbMhaQww,spotif...
# 2  2FwDApgXk91kXvqy2oB7dz  spotify:playlist:1w7Ov7WTgX1YNQlbMhaQww,spotif...
# 3  3HFBqhotJeEKHJzMEW31jZ            spotify:playlist:1w7Ov7WTgX1YNQlbMhaQww
# 4  4PwWESSlTwzvw9B7bmtTLS  spotify:playlist:1w7Ov7WTgX1YNQlbMhaQww,spotif...
#
#    danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0         0.340   0.924   1.0    -5.077   1.0       0.0347         0.256
# 1         0.848   0.541   4.0    -9.305   1.0       0.0668         0.493
# 2         0.703   0.578   1.0    -9.103   1.0       0.0728         0.446
# 3         0.633   0.161  10.0   -12.892   1.0       0.0613         0.830
# 4         0.388   0.291   3.0   -12.952   1.0       0.0421         0.774
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0          0.925000    0.2480    0.736   96.104     344823.0             4.0
# 1          0.000000    0.1110    0.768  109.909     184907.0             4.0
# 2          0.002400    0.1020    0.670  105.204     252734.0             4.0
# 3          0.000099    0.2630    0.546  132.570     295454.0             4.0
# 4          0.000019    0.0874    0.510   83.943     202047.0             4.0
#
#          primary_playlist
# 0  Tail end of the summer
# 1  Tail end of the summer
# 2  Tail end of the summer
# 3  Tail end of the summer
# 4  Tail end of the summer

# %%
len('spotify:track:5ZlfX4evbtQtONINsLADDR')
# Out:
# 36

# %%
df['uri']
# Out:
# 0       spotify:track:5ZlfX4evbtQtONINsLADDR
# 1       spotify:track:2ltjgZUx2DgxdYGxuyhNAd
# 2       spotify:track:2FwDApgXk91kXvqy2oB7dz
# 3       spotify:track:3HFBqhotJeEKHJzMEW31jZ
# 4       spotify:track:4PwWESSlTwzvw9B7bmtTLS
#                         ...
# 9297    spotify:track:4fYAcwdEtW2VCZe5Xoe7iC
# 9298    spotify:track:11c4nID11cj01SsG86RpNR
# 9299    spotify:local:Pignoise:Todo+exitos+M
# 9300    spotify:track:2sG9YM9Vuw3wdkWxJV5f90
# 9301    spotify:track:0IZM2onaTBMRTEIcc5oIi9
# Name: uri, Length: 9302, dtype: object

# %%
import umap
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler

# Select only the numerical audio feature columns
audio_features = [
    'danceability', 'energy', 'key', 'loudness', 'mode',
    'speechiness', 'acousticness', 'instrumentalness',
    'liveness', 'valence', 'tempo'
]

# Prepare the data and handle missing values
X = df[audio_features].copy()
X = X.apply(pd.to_numeric, errors='coerce')  # Convert to numeric
X = X.fillna(X.mean())  # Fill NaN with mean values

# Convert to numpy array
X_array = X.values

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_array)

# Create and fit UMAP
reducer = umap.UMAP(
    n_neighbors=15,
    min_dist=0.1,
    n_components=2,
    random_state=42
)
embedding = reducer.fit_transform(X_scaled)
# Out:
# /Users/dani/.virtualenvs/animus/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.

# %%
import plotly.express as px

playlists = [
    'Tail end of the summer',
    'retrofuturism'
]

plot_df = pd.DataFrame({
    'UMAP1': embedding[:, 0],
    'UMAP2': embedding[:, 1],
    'Playlist': df['primary_playlist'],
    'Track': df['name'],
    'Artist': df['artists'],
    'Danceability': df['danceability'],
    'Energy': df['energy'],
    'Valence': df['valence']
})

plot_df = plot_df[plot_df['Playlist'].isin(playlists)]


fig = px.scatter(
    plot_df,
    x='UMAP1',
    y='UMAP2',
    color='Playlist',
    hover_data=['Track', 'Artist', 'Danceability', 'Energy', 'Valence'],
    title='Interactive UMAP Projection of Spotify Tracks',
    labels={'UMAP1': 'UMAP Dimension 1', 'UMAP2': 'UMAP Dimension 2'},
    color_discrete_sequence=px.colors.qualitative.Set3
)

# Update layout for better visualization
fig.update_layout(
    plot_bgcolor='white',
    width=1200,
    height=800,
    legend=dict(
        yanchor="top",
        y=0.99,
        xanchor="left",
        x=1.02
    ),
    margin=dict(r=300)  # Make room for the legend
)

# Update traces
fig.update_traces(
    marker=dict(size=8),
    opacity=0.7
)

# Add gridlines
fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='LightGray')
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='LightGray')

# Show the plot
fig.show()

# Store the UMAP coordinates in the original dataframe if needed
df['umap_1'] = embedding[:, 0]
df['umap_2'] = embedding[:, 1]

# %%
df['primary_playlist'] = df['playlist_uris'].apply(get_primary_playlist)

# %%
df.head()
# Out:
#                name          artists                                   uri  \
# 0     Little Things        Big Thief  spotify:track:5ZlfX4evbtQtONINsLADDR
# 1        Palm Beach   Vicente Garcia  spotify:track:2ltjgZUx2DgxdYGxuyhNAd
# 2  Simulation Swarm        Big Thief  spotify:track:2FwDApgXk91kXvqy2oB7dz
# 3            Change        Big Thief  spotify:track:3HFBqhotJeEKHJzMEW31jZ
# 4          anything  Adrianne Lenker  spotify:track:4PwWESSlTwzvw9B7bmtTLS
#
#                        id                                      playlist_uris  \
# 0  5ZlfX4evbtQtONINsLADDR          [spotify:playlist:1w7Ov7WTgX1YNQlbMhaQww]
# 1  2ltjgZUx2DgxdYGxuyhNAd  [spotify:playlist:1w7Ov7WTgX1YNQlbMhaQww, spot...
# 2  2FwDApgXk91kXvqy2oB7dz  [spotify:playlist:1w7Ov7WTgX1YNQlbMhaQww, spot...
# 3  3HFBqhotJeEKHJzMEW31jZ          [spotify:playlist:1w7Ov7WTgX1YNQlbMhaQww]
# 4  4PwWESSlTwzvw9B7bmtTLS  [spotify:playlist:1w7Ov7WTgX1YNQlbMhaQww, spot...
#
#    danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0         0.340   0.924   1.0    -5.077   1.0       0.0347         0.256
# 1         0.848   0.541   4.0    -9.305   1.0       0.0668         0.493
# 2         0.703   0.578   1.0    -9.103   1.0       0.0728         0.446
# 3         0.633   0.161  10.0   -12.892   1.0       0.0613         0.830
# 4         0.388   0.291   3.0   -12.952   1.0       0.0421         0.774
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0          0.925000    0.2480    0.736   96.104     344823.0             4.0
# 1          0.000000    0.1110    0.768  109.909     184907.0             4.0
# 2          0.002400    0.1020    0.670  105.204     252734.0             4.0
# 3          0.000099    0.2630    0.546  132.570     295454.0             4.0
# 4          0.000019    0.0874    0.510   83.943     202047.0             4.0
#
#          primary_playlist
# 0  Tail end of the summer
# 1  Tail end of the summer
# 2  Tail end of the summer
# 3  Tail end of the summer
# 4  Tail end of the summer

# %% [markdown]
# ## Use additional description chain

# %%
from animus import generate_playlist_description, generate_aspects_description
target = 'un paquete de tabaco de liar encima de la mesa de una terraza'
aspects = generate_aspects_description(target)
description = generate_playlist_description(target, aspects)
print(description)
# Out:
# For this quintessentially Mediterranean terrace scene with its rolling tobacco, I recommend focusing on Spanish and Latin genres that capture both the urban café culture and the leisurely outdoor atmosphere. The playlist should primarily feature salsa and spanish genres, with a moderate tempo (85-110 BPM) reflecting the unhurried pace of terrace life. I think we should stick exclusively to these genres to maintain the cultural authenticity of the scene. The tracks should have medium energy (0.4-0.6) – energetic enough to match the urban setting but relaxed enough for casual smoking and conversation. The acousticness should be relatively high (0.6-0.8) to complement the outdoor setting, with a good mix of traditional instruments. The liveness parameter should be moderate (0.3-0.5) to capture some ambient crowd feeling without overwhelming the mood. Valence should be positive (0.6-0.8) reflecting the leisure activity, but not excessively upbeat. The instrumentalness should vary (0.2-0.6) allowing for both vocal and instrumental tracks, mirroring the flow of conversation and comfortable silences at the table. Loudness should be moderate (-12 to -8 dB) to match the outdoor café atmosphere. The music should favor major keys to maintain the light, social mood, but with enough complexity in the arrangements to reward attentive listening during contemplative smoking moments.

# %%
from animus import generate_spotify_parameters
spotify_params = generate_spotify_parameters(description)
print(spotify_params)
# Out:
# {'seed_genres': ['salsa', 'spanish', 'latin'], 'min_tempo': 85, 'max_tempo': 110, 'min_energy': 0.4, 'max_energy': 0.6, 'min_acousticness': 0.6, 'max_acousticness': 0.8, 'min_liveness': 0.3, 'max_liveness': 0.5, 'min_valence': 0.6, 'max_valence': 0.8, 'min_instrumentalness': 0.2, 'max_instrumentalness': 0.6, 'min_loudness': -12, 'max_loudness': -8, 'target_mode': 1}
